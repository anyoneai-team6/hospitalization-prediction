# %%
for i in range(2,50):
    print(f"<div class=\"mb-3 col-3\" id=\"Question{i}\">"
          f"<p>Question {i}:</p>"
          "<div class=\"form-check form-check-inline\">"
          "  <input"
          "    class=\"form-check-input\""
          "    type=\"radio\""
          f"    name=\"Question{i}\""
          "    id=\"inlineRadio1\""
          "    value=\"Yes\""
          "/>"
          "  <label class=\"form-check-label\" for=\"inlineRadio1\">Yes</label>"
          "</div>"
          "<div class=\"form-check form-check-inline\">"
          "  <input"
          "    class=\"form-check-input\""
          "    type=\"radio\""
          f"    name=\"Question{i}\""
          "    id=\"inlineRadio2\""
          "    value=\"No\""
          "/>"
          "  <label class=\"form-check-label\" for=\"inlineRadio2\">No</label>"
          "</div>"
          "<div class=\"form-check form-check-inline\">"
          "  <input"
          "    class=\"form-check-input\""
          "    type=\"radio\""
          f"    name=\"Question{i}\""
          "    id=\"inlineRadio3\""
          "    value=\"I don't know\""
          "/>"
          "  <label class=\"form-check-label\" for=\"inlineRadio3\">I don't know</label>"
          "</div>"
          "</div>")
# Out:
# <div class="mb-3 col-3" id="Question2"><p>Question 2:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question2"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question2"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question2"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question3"><p>Question 3:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question3"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question3"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question3"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question4"><p>Question 4:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question4"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question4"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question4"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question5"><p>Question 5:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question5"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question5"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question5"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question6"><p>Question 6:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question6"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question6"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question6"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question7"><p>Question 7:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question7"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question7"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question7"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question8"><p>Question 8:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question8"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question8"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question8"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question9"><p>Question 9:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question9"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question9"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question9"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question10"><p>Question 10:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question10"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question10"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question10"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question11"><p>Question 11:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question11"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question11"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question11"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question12"><p>Question 12:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question12"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question12"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question12"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question13"><p>Question 13:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question13"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question13"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question13"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question14"><p>Question 14:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question14"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question14"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question14"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question15"><p>Question 15:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question15"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question15"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question15"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question16"><p>Question 16:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question16"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question16"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question16"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question17"><p>Question 17:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question17"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question17"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question17"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question18"><p>Question 18:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question18"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question18"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question18"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question19"><p>Question 19:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question19"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question19"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question19"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question20"><p>Question 20:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question20"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question20"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question20"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question21"><p>Question 21:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question21"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question21"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question21"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question22"><p>Question 22:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question22"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question22"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question22"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question23"><p>Question 23:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question23"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question23"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question23"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question24"><p>Question 24:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question24"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question24"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question24"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question25"><p>Question 25:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question25"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question25"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question25"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question26"><p>Question 26:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question26"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question26"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question26"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question27"><p>Question 27:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question27"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question27"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question27"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question28"><p>Question 28:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question28"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question28"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question28"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question29"><p>Question 29:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question29"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question29"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question29"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question30"><p>Question 30:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question30"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question30"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question30"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question31"><p>Question 31:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question31"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question31"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question31"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question32"><p>Question 32:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question32"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question32"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question32"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question33"><p>Question 33:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question33"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question33"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question33"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question34"><p>Question 34:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question34"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question34"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question34"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question35"><p>Question 35:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question35"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question35"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question35"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question36"><p>Question 36:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question36"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question36"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question36"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question37"><p>Question 37:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question37"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question37"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question37"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question38"><p>Question 38:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question38"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question38"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question38"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question39"><p>Question 39:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question39"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question39"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question39"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question40"><p>Question 40:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question40"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question40"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question40"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question41"><p>Question 41:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question41"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question41"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question41"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question42"><p>Question 42:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question42"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question42"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question42"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question43"><p>Question 43:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question43"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question43"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question43"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question44"><p>Question 44:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question44"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question44"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question44"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question45"><p>Question 45:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question45"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question45"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question45"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question46"><p>Question 46:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question46"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question46"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question46"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question47"><p>Question 47:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question47"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question47"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question47"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question48"><p>Question 48:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question48"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question48"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question48"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
# <div class="mb-3 col-3" id="Question49"><p>Question 49:</p><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question49"    id="inlineRadio1"    value="Yes"/>  <label class="form-check-label" for="inlineRadio1">Yes</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question49"    id="inlineRadio2"    value="No"/>  <label class="form-check-label" for="inlineRadio2">No</label></div><div class="form-check form-check-inline">  <input    class="form-check-input"    type="radio"    name="Question49"    id="inlineRadio3"    value="I don't know"/>  <label class="form-check-label" for="inlineRadio3">I don't know</label></div></div>
